# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x_train=np.array([1.0, 2.0])
y_train=np.array([300.0,500.0])
print(f"x_train={x_train}")
print(f"y_train={y_train}")
# Out:
# x_train=[1. 2.]
# y_train=[300. 500.]

# %%
print(f"x_train.shape={x_train.shape}")
m=x_train.shape[0]
print(f"number of sets: {m}")
# Out:
# x_train.shape=(2,)
# number of sets: 2

# %%
m=len(x_train)
print(f"number of training examples: {m}")
# Out:
# number of training examples: 2

# %%
i=0
x_i=x_train[i]
y_i=y_train[i]
print(f"(x^{i}),(y^{i})=({x_i},{y_i})")
# Out:
# (x^0),(y^0)=(1.0,300.0)

# %%
plt.scatter(x_train, y_train, marker="x", c="r")
plt.title="housing prices"
plt.ylabel=("price(is in 1000 dollars)")
plt.xlabel=("size(is in 1000 sqft)")
plt.show()

# %%
w=200
b=100
print(f"w:{w}")
print(f"b: {b}")
# Out:
# w:200
# b: 100

# %%
def compute_model_output(x,w,b):
    m=x.shape[0]
    f_wb=np.zeros(m)
for i in range(m):
    f_wb[i]=w*x[i]+b
return f_wb
# Out:
# -----------------------------------------------------------------
# NameError                       Traceback (most recent call last)
# Cell In[42], line 5
#       1 def compute_model_output(x,w,b):
#       2     m=x.shape[0]
#       3     f_wb=np.zeros(m)
#       4 for i in range(m):
# ----> 5     f_wb[i]=w*x[i]+b
#       6 return f_wb
#       7
#
# NameError: name 'x' is not defined

# %%
tmp_f_wb = compute_model_output(x_train, w, b)

# Plot our model prediction
plt.plot(x_train, tmp_f_wb, c="b",label="Our Prediction")

# Plot the data points
plt.scatter(x_train, y_train, marker="x", c="r",label="Actual Values")

# Set the title
plt.title("Housing Prices")
# Set the y-axis label
plt.ylabel('Price (in 1000s of dollars)')
# Set the x-axis label
plt.xlabel('Size (1000 sqft)')
plt.legend()
plt.show()
# Out:
# -----------------------------------------------------------------
# ValueError                      Traceback (most recent call last)
# Cell In[43], line 4
#       1 tmp_f_wb = compute_model_output(x_train, w, b)
#       2
#       3 # Plot our model prediction
# ----> 4 plt.plot(x_train, tmp_f_wb, c="b",label="Our Prediction")
#       5
#       6 # Plot the data points
#       7 plt.scatter(x_train, y_train, marker="x", c="r",label="Actual Values")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\pyplot.py:4043, in plot(scalex, scaley, data, *args, **kwargs)
#    4035 @_copy_docstring_and_deprecators(Axes.plot)
#    4036 def plot(
#    4037     *args: float | ArrayLike | str,
#    (...)   4041     **kwargs,
#    4042 ) -> list[Line2D]:
# -> 4043     return gca().plot(
#    4044         *args,
#    4045         scalex=scalex,
#    4046         scaley=scaley,
#    4047         **({"data": data} if data is not None else {}),
#    4048         **kwargs,
#    4049     )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_axes.py:1792, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1549 """
#    1550 Plot y versus x as lines and/or markers.
#    1551
#    (...)   1789 (``'green'``) or hex strings (``'#008000'``).
#    1790 """
#    1791 kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1792 lines = [*self._get_lines(self, *args, data=data, **kwargs)]
#    1793 for line in lines:
#    1794     self.add_line(line)
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_base.py:331, in _process_plot_var_args.__call__(self, axes, data, return_kwargs, *args, **kwargs)
#     329     this += args[0],
#     330     args = args[1:]
# --> 331 yield from self._plot_args(
#     332     axes, this, kwargs, ambiguous_fmt_datakey=ambiguous_fmt_datakey,
#     333     return_kwargs=return_kwargs
#     334 )
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\matplotlib\axes\_base.py:470, in _process_plot_var_args._plot_args(self, axes, tup, kwargs, return_kwargs, ambiguous_fmt_datakey)
#     467 # Don't allow any None value; these would be up-converted to one
#     468 # element array of None which causes problems downstream.
#     469 if any(v is None for v in tup):
# --> 470     raise ValueError("x, y, and format string must not be None")
#     472 kw = {}
#     473 for prop_name, val in zip(('linestyle', 'marker', 'color'),
#     474                           (linestyle, marker, color)):
#
# ValueError: x, y, and format string must not be None
