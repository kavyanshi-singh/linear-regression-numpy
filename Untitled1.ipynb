# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib widget
from lab_utlis_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
# Out:
# -----------------------------------------------------------------
# ModuleNotFoundError             Traceback (most recent call last)
# Cell In[3], line 4
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 get_ipython().run_line_magic('matplotlib', 'widget')
# ----> 4 from lab_utlis_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
#
# ModuleNotFoundError: No module named 'lab_utlis_uni'
